# %% [markdown]
# <a href="https://colab.research.google.com/github/yousifalasfar/yousifalasfar/blob/main/YA_Pandas_datetime_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas Date&time Methods**
#
# In Python, date and time are not a data type of their own, but a module named datetime can be imported to work with the date as well as time. Python Datetime module comes built into Python, so there is no need to install it externally.

# %% [markdown]
#  **System Requierments**
#
# *   Jupyter Notebook (in VScode, Google Colab, or Anaconda), Python, and Requests.

# %% [markdown]
# **Installations & Imports**

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
#Read the csv file
df =(pd.
read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Pandas/10-Datetime-Timeseries/ETH_1h.csv')
)
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
# Jsut to give you an idea about the dats you're wroking on (rows, columns)
df.shape
# Out:
# (23674, 7)

# %%
#Check the dtype of cloumns and notice that date is ab object
df.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %% [markdown]
# ---> **to_datetime**
#
# *  In order to to use datetime functions on a column,  dtype the of column must be datetime
#
# *   We can convert column to datetime by using to_datetime()

# %% [markdown]
# Strptime(str, format)
# *   This function takes a string and format as an arrguments and to converts the string to time object

# %%
pd.datetime.strptime(df.iloc[0,0], '%Y-%M-%d %H-%p')
# Out:
# datetime.datetime(2020, 1, 13, 8, 3)

# %% [markdown]
# *  We need to convert Date column to datetime using to_datetime()
# * In order for datetime to work we need to tell pandas which fromat we wish it to be
# * Here is a link to docs for formatting symbols for python in general
# * https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
# %I Hour (12-hour clock) as a zero-padded decimal number.
#%p Locale’s equivalent of either AM or PM.

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
#Check again!!
df.Date

# It's datetime64[ns] now
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
# We can convert to utc 
df['Date'] = pd.to_datetime(df['Date'], utc=True)
df
# Out:
#                            Date  Symbol    Open    High     Low   Close  \
# 0     2020-03-13 20:00:00+00:00  ETHUSD  129.94  131.82  126.87  128.71
# 1     2020-03-13 19:00:00+00:00  ETHUSD  119.51  132.02  117.10  129.94
# 2     2020-03-13 18:00:00+00:00  ETHUSD  124.47  124.85  115.50  119.51
# 3     2020-03-13 17:00:00+00:00  ETHUSD  124.08  127.42  121.63  124.47
# 4     2020-03-13 16:00:00+00:00  ETHUSD  124.85  129.51  120.17  124.08
# ...                         ...     ...     ...     ...     ...     ...
# 23669 2017-07-01 15:00:00+00:00  ETHUSD  265.74  272.74  265.00  272.57
# 23670 2017-07-01 14:00:00+00:00  ETHUSD  268.79  269.90  265.00  265.74
# 23671 2017-07-01 13:00:00+00:00  ETHUSD  274.83  274.93  265.00  268.79
# 23672 2017-07-01 12:00:00+00:00  ETHUSD  275.01  275.01  271.00  274.83
# 23673 2017-07-01 11:00:00+00:00  ETHUSD  279.98  279.99  272.10  275.01
#
#            Volume
# 0      1940673.93
# 1      7579741.09
# 2      4898735.81
# 3      2753450.92
# ...

# %%
parser = lambda x: datetime.strptime(x, '%Y-%m-%d %H-%p')
df =pd.read_csv('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Pandas/10-Datetime-Timeseries/ETH_1h.csv', parse_dates=['Date'], date_parser=parser)
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 08:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 07:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 06:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 05:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 04:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 03:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 02:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 01:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %% [markdown]
# **--> to_timedelta**
#
#
# *  Timedeltas are absolute differences in times, expressed in difference units (e.g. days, hours, minutes, seconds).
# *  This method converts an argument from a recognized timedelta format / value into a Timedelta type.

# %%
# we can create a Timedelta object as shown below:
year = timedelta(days=365)
another_year = timedelta(weeks=40, days=84, hours=23,
                         minutes=50, seconds=600)
year == another_year
# Out:
# True

# %%
#More functions like days, seconds etc.
ten_years = 10 * year
ten_years.days
# Out:
# 3650

# %%
#More functions like days, seconds etc.
year.total_seconds()
# Out:
# 31536000.0

# %%
#Once we have a datetime object, we can use the timedelta class to add time to it.
#Exsample will show possible arguments and they all optional too
ti = df.iloc[0,0] + timedelta(weeks=2, days=2,hours=2,  minutes=25, seconds=24)
ti
# Out:
# Timestamp('2020-03-29 10:25:24')

# %%
#Might use it to get a current date & time too
datetime.today()
# Out:
# datetime.datetime(2022, 10, 11, 18, 0, 43, 991995)

# %%
pd.Timedelta(days=2)
# Out:
# Timedelta('2 days 00:00:00')

# %% [markdown]
# **-->Timetamp**

# %%
pd.Timestamp(df.iloc[0,0], unit='s', tz='Europe/Stockholm')
# Out:
# Timestamp('2020-03-13 08:00:00+0100', tz='Europe/Stockholm')

# %% [markdown]
# Once we have our time coverted to datetime object then will have access to more functionaly.

# %%
# NOW we can run functions Like day_name() or .year, .month, .day etc
df.iloc[0,0].year
df.iloc[0,0].month
df.iloc[0,0].day
df.iloc[0,0].day_name()
df.iloc[0,0].date()
# Out:
# datetime.date(2020, 3, 13)

# %%
#You can run the previuos func on a list or series of values by usig dt class
df.Date.dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
#You might use the above code to create a cloumn for easy refrence
#used insert just to re-order columns
df['Day'] = df.Date.dt.day_name()
df.insert(1, 'Day', df.pop('Day'))
df
# Out:
#                      Date       Day  Symbol    Open    High     Low   Close  \
# 0     2020-03-13 08:00:00    Friday  ETHUSD  129.94  131.82  126.87  128.71
# 1     2020-03-13 07:00:00    Friday  ETHUSD  119.51  132.02  117.10  129.94
# 2     2020-03-13 06:00:00    Friday  ETHUSD  124.47  124.85  115.50  119.51
# 3     2020-03-13 05:00:00    Friday  ETHUSD  124.08  127.42  121.63  124.47
# 4     2020-03-13 04:00:00    Friday  ETHUSD  124.85  129.51  120.17  124.08
# ...                   ...       ...     ...     ...     ...     ...     ...
# 23669 2017-07-01 03:00:00  Saturday  ETHUSD  265.74  272.74  265.00  272.57
# 23670 2017-07-01 02:00:00  Saturday  ETHUSD  268.79  269.90  265.00  265.74
# 23671 2017-07-01 01:00:00  Saturday  ETHUSD  274.83  274.93  265.00  268.79
# 23672 2017-07-01 12:00:00  Saturday  ETHUSD  275.01  275.01  271.00  274.83
# 23673 2017-07-01 11:00:00  Saturday  ETHUSD  279.98  279.99  272.10  275.01
#
#            Volume
# 0      1940673.93
# ...

# %%
# The earliest date by max() and the oldest date bt min()
#The most recent
df.Date.max()
# Out:
# Timestamp('2020-03-13 12:00:00')

# %%
# The Oldest
df.Date.min()
# Out:
# Timestamp('2017-07-01 01:00:00')

# %%
#The differnce between date would five the timedelta or the time between in days and hours
df.Date.max() - df.Date.min()
# Out:
# Timedelta('986 days 11:00:00')

# %%
#We can filter the data  we can get a data range or comperison
filter = df.Date > '2019-03-20'
df.loc[filter]
# Out:
#                     Date        Day  Symbol    Open    High     Low   Close  \
# 0    2020-03-13 08:00:00     Friday  ETHUSD  129.94  131.82  126.87  128.71
# 1    2020-03-13 07:00:00     Friday  ETHUSD  119.51  132.02  117.10  129.94
# 2    2020-03-13 06:00:00     Friday  ETHUSD  124.47  124.85  115.50  119.51
# 3    2020-03-13 05:00:00     Friday  ETHUSD  124.08  127.42  121.63  124.47
# 4    2020-03-13 04:00:00     Friday  ETHUSD  124.85  129.51  120.17  124.08
# ...                  ...        ...     ...     ...     ...     ...     ...
# 8632 2019-03-20 04:00:00  Wednesday  ETHUSD  136.80  136.93  136.65  136.92
# 8633 2019-03-20 03:00:00  Wednesday  ETHUSD  137.15  137.17  136.78  136.80
# 8634 2019-03-20 02:00:00  Wednesday  ETHUSD  136.93  137.18  136.93  137.15
# 8635 2019-03-20 01:00:00  Wednesday  ETHUSD  136.54  137.12  136.54  136.93
# 8636 2019-03-20 12:00:00  Wednesday  ETHUSD  138.15  138.41  136.43  136.54
#
#           Volume
# 0     1940673.93
# 1     7579741.09
# ...

# %%
#We can filter the data  we can get a data range or comperison
# I don't know why I say greater than > and it's the same as >=
filter = (df['Date'] > '2019-03-20') & (df['Date'] < '2020-03-20')
#filter = (df.Date > pd.to_datetime('2019-03-20')) & (df.Date < pd.to_datetime('2020-03-20'))
df.loc[filter]
# Out:
#                     Date        Day  Symbol    Open    High     Low   Close  \
# 0    2020-03-13 08:00:00     Friday  ETHUSD  129.94  131.82  126.87  128.71
# 1    2020-03-13 07:00:00     Friday  ETHUSD  119.51  132.02  117.10  129.94
# 2    2020-03-13 06:00:00     Friday  ETHUSD  124.47  124.85  115.50  119.51
# 3    2020-03-13 05:00:00     Friday  ETHUSD  124.08  127.42  121.63  124.47
# 4    2020-03-13 04:00:00     Friday  ETHUSD  124.85  129.51  120.17  124.08
# ...                  ...        ...     ...     ...     ...     ...     ...
# 8632 2019-03-20 04:00:00  Wednesday  ETHUSD  136.80  136.93  136.65  136.92
# 8633 2019-03-20 03:00:00  Wednesday  ETHUSD  137.15  137.17  136.78  136.80
# 8634 2019-03-20 02:00:00  Wednesday  ETHUSD  136.93  137.18  136.93  137.15
# 8635 2019-03-20 01:00:00  Wednesday  ETHUSD  136.54  137.12  136.54  136.93
# 8636 2019-03-20 12:00:00  Wednesday  ETHUSD  138.15  138.41  136.43  136.54
#
#           Volume
# 0     1940673.93
# 1     7579741.09
# ...

# %% [markdown]
# ##Indexing Date

# %% [markdown]
# We can pass Date to our index and then filter by passing the date directley

# %%
#Set the Dat cloumn to index
df.set_index('Date', inplace=True)
df
# Out:
#                           Day  Symbol    Open    High     Low   Close  \
# Date
# 2020-03-13 08:00:00    Friday  ETHUSD  129.94  131.82  126.87  128.71
# 2020-03-13 07:00:00    Friday  ETHUSD  119.51  132.02  117.10  129.94
# 2020-03-13 06:00:00    Friday  ETHUSD  124.47  124.85  115.50  119.51
# 2020-03-13 05:00:00    Friday  ETHUSD  124.08  127.42  121.63  124.47
# 2020-03-13 04:00:00    Friday  ETHUSD  124.85  129.51  120.17  124.08
# ...                       ...     ...     ...     ...     ...     ...
# 2017-07-01 03:00:00  Saturday  ETHUSD  265.74  272.74  265.00  272.57
# 2017-07-01 02:00:00  Saturday  ETHUSD  268.79  269.90  265.00  265.74
# 2017-07-01 01:00:00  Saturday  ETHUSD  274.83  274.93  265.00  268.79
# 2017-07-01 12:00:00  Saturday  ETHUSD  275.01  275.01  271.00  274.83
# 2017-07-01 11:00:00  Saturday  ETHUSD  279.98  279.99  272.10  275.01
#
#                          Volume
# Date
# 2020-03-13 08:00:00  1940673.93
# 2020-03-13 07:00:00  7579741.09
# ...

# %%
#So now we can filter easy like this
df['2019']
#Or get a range of data
df['2019-10' : '2020-02']
df['2019-11']
# Out:
#                           Day  Symbol    Open    High     Low   Close  \
# Date
# 2019-11-30 11:00:00  Saturday  ETHUSD  151.58  152.36  151.58  151.78
# 2019-11-30 10:00:00  Saturday  ETHUSD  152.10  153.55  151.58  151.58
# 2019-11-30 09:00:00  Saturday  ETHUSD  150.99  152.40  150.89  152.10
# 2019-11-30 08:00:00  Saturday  ETHUSD  150.68  151.17  150.24  150.99
# 2019-11-30 07:00:00  Saturday  ETHUSD  150.29  151.35  150.29  150.68
# ...                       ...     ...     ...     ...     ...     ...
# 2019-11-01 04:00:00    Friday  ETHUSD  180.63  181.28  180.46  181.17
# 2019-11-01 03:00:00    Friday  ETHUSD  182.29  182.36  180.48  180.63
# 2019-11-01 02:00:00    Friday  ETHUSD  181.86  182.48  181.62  182.29
# 2019-11-01 01:00:00    Friday  ETHUSD  182.24  183.09  181.86  181.86
# 2019-11-01 12:00:00    Friday  ETHUSD  182.38  182.44  181.51  182.24
#
#                         Volume
# Date
# 2019-11-30 11:00:00  317114.79
# 2019-11-30 10:00:00  876578.44
# ...

# %%
#you could simply pass in a year (in the format 'yyyy') or year-month parts ('yyyy-mm').
df.loc['2019', 'Close'] #This would return data for the whole year
df.loc['2019-09', 'Close'] #This would return the data for the whole month in that year
# Out:
# Date
# 2019-09-30 11:00:00    181.17
# 2019-09-30 10:00:00    177.54
# 2019-09-30 09:00:00    177.56
# 2019-09-30 08:00:00    176.99
# 2019-09-30 07:00:00    178.13
#                         ...
# 2019-09-01 04:00:00    172.77
# 2019-09-01 03:00:00    172.75
# 2019-09-01 02:00:00    172.84
# 2019-09-01 01:00:00    172.87
# 2019-09-01 12:00:00    172.71
# Name: Close, Length: 720, dtype: float64

# %%
#We can set timedelat to specify how frequent we want to see the data details, days, hours ... 
s = pd.Series(pd.date_range('2018-1-01', periods=3, freq='W'))
# S now is a weekly date range for 4 weeks
# 0   2018-01-07
# 1   2018-01-14
# 2   2018-01-21
# 3   2018-01-28
td = pd.Series([pd.Timedelta(weeks=i) for i in range(3)])
td
#td now is 4 sets of 7days
# 0    0 days
# 1    7 days
# 2   14 days
# 3   21 days
test = pd.DataFrame(dict(A = s, B = td))
test
test.A
test.B
set1= [str(x.date())for x in (test.A + test.B)]
set1
# Out:
# ['2018-01-07', '2018-01-21', '2018-02-04']

# %%
[df[x] for x in set1]
# Out:
# [                        Day  Symbol     Open     High      Low    Close  \
#  Date
#  2018-01-07 11:00:00  Sunday  ETHUSD  1090.35  1118.30  1090.35  1118.30
#  2018-01-07 10:00:00  Sunday  ETHUSD  1093.00  1093.00  1079.19  1090.35
#  2018-01-07 09:00:00  Sunday  ETHUSD  1093.01  1095.00  1082.39  1093.00
#  2018-01-07 08:00:00  Sunday  ETHUSD  1094.57  1098.87  1093.00  1093.01
#  2018-01-07 07:00:00  Sunday  ETHUSD  1080.43  1095.00  1080.43  1094.57
#  2018-01-07 06:00:00  Sunday  ETHUSD  1088.84  1093.00  1064.08  1080.43
#  2018-01-07 05:00:00  Sunday  ETHUSD  1090.00  1098.50  1082.80  1088.84
#  2018-01-07 04:00:00  Sunday  ETHUSD  1088.99  1098.30  1079.94  1090.00
#  2018-01-07 03:00:00  Sunday  ETHUSD  1075.00  1088.99  1070.02  1088.99
#  2018-01-07 02:00:00  Sunday  ETHUSD  1062.99  1077.04  1062.99  1075.00
#  2018-01-07 01:00:00  Sunday  ETHUSD  1073.46  1073.67  1053.81  1062.99
#  2018-01-07 12:00:00  Sunday  ETHUSD  1073.57  1077.00  1065.95  1073.46
# ...

# %%
set2 = [df[x].resample('W').mean() for x in set1]
set2
#set2[0]
# Out:
# [                   Open         High       Low        Close        Volume
#  Date
#  2018-01-07  1065.344583  1074.455417  1058.025  1069.995417  7.354962e+06,
#                     Open        High          Low       Close        Volume
#  Date
#  2018-01-21  1077.290833  1090.88375  1062.087083  1073.00375  6.588510e+06,
#                Open    High     Low    Close        Volume
#  Date
#  2018-02-04  902.08  911.01  885.98  896.105  7.478161e+06]

# %% [markdown]
# ##Resampling Pandas DataFrames using DateTimes
#
# The Pandas .resample() method allows you to resample a dataset with a timeseries index. The method accepts a periodicity that you want to resample to, such as 'W' for week or 'H' for hour. Since you’ll want to provide some method by which to invent your data, you can chain in another method, such as .mean(), max(), etc. to resample with that aggregation function. Let’s resample our hourly data to daily data

# %%
#resampling Yearly
# Y = year, M = month, W = week, D =day, H = hour
df.resample('Y').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-12-31  351.863442  354.775251  348.692225  351.966277  2.948845e+06
# 2018-12-31  481.001922  484.673551  476.769732  480.932120  2.733347e+06
# 2019-12-31  180.752257  181.766612  179.656623  180.752030  9.360009e+05
# 2020-12-31  197.568662  199.030543  195.993762  197.568759  1.415723e+06

# %%
# Resampling Data with Different Methods
df.resample('M').agg({
    'Close': 'last',
    'High': 'max',
    'Low': 'min',
    'Open': 'first',
    'Volume': 'sum'
})
# Out:
#               Close     High     Low     Open        Volume
# Date
# 2017-07-31   195.31   293.73  130.26   274.83  1.818282e+09
# 2017-08-31   383.86   392.00  200.82   219.00  1.529929e+09
# 2017-09-30   295.36   396.88  202.25   395.19  1.678947e+09
# 2017-10-31   309.16   350.00  275.46   300.50  8.155377e+08
# 2017-11-30   447.51   518.13  278.88   297.45  1.974056e+09
# 2017-12-31   716.44   875.00  415.01   443.03  5.172910e+09
# 2018-01-31  1029.10  1419.96  727.14   750.50  7.728885e+09
# 2018-02-28   876.55  1143.00  555.56  1113.99  4.123206e+09
# 2018-03-31   404.21   878.00  365.00   863.29  2.028503e+09
# 2018-04-30   691.69   711.00  360.00   377.01  1.899357e+09
# 2018-05-31   560.00   828.97  507.00   650.97  2.241083e+09
# 2018-06-30   441.41   627.83  404.22   573.85  1.254270e+09
# 2018-07-31   454.68   515.88  418.23   448.41  7.496308e+08
# 2018-08-31   280.75   435.48  250.28   423.18  9.676426e+08
# 2018-09-30   230.48   302.20  167.00   284.89  1.006817e+09
# ...

# %% [markdown]
# **--> date_range**
#
#
# * Returns the range of equally spaced time points (where the difference between
# any two adjacent points is specified by the given frequency)

# %%
#Returns the range of dates we want
pd.date_range(start='1/1/2018', end='1/08/2018')
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
#Specify start, end or both date and periods, the number of periods (days).
pd.date_range(end='1/1/2018', periods=8)
pd.date_range(start='1/1/2018', periods=8)
test = pd.date_range(start='2017-07-01', end='2017-07-10', periods=1)
for x in test:
  print(df[str(x.date())])
# Out:
#                           Day  Symbol    Open    High     Low   Close  \
# Date
# 2017-07-01 11:00:00  Saturday  ETHUSD  263.84  264.97  260.31  263.12
# 2017-07-01 10:00:00  Saturday  ETHUSD  257.13  264.36  256.03  263.84
# 2017-07-01 09:00:00  Saturday  ETHUSD  258.17  260.56  254.15  257.13
# 2017-07-01 08:00:00  Saturday  ETHUSD  258.49  262.00  257.12  258.17
# 2017-07-01 07:00:00  Saturday  ETHUSD  259.50  260.88  253.23  258.49
# 2017-07-01 06:00:00  Saturday  ETHUSD  263.51  266.73  255.27  259.50
# 2017-07-01 05:00:00  Saturday  ETHUSD  268.00  268.44  262.39  263.51
# 2017-07-01 04:00:00  Saturday  ETHUSD  272.57  272.57  267.60  268.00
# 2017-07-01 03:00:00  Saturday  ETHUSD  265.74  272.74  265.00  272.57
# 2017-07-01 02:00:00  Saturday  ETHUSD  268.79  269.90  265.00  265.74
# 2017-07-01 01:00:00  Saturday  ETHUSD  274.83  274.93  265.00  268.79
# 2017-07-01 12:00:00  Saturday  ETHUSD  275.01  275.01  271.00  274.83
# ...

# %%
#Changed the freq (frequency) to 'M' (month end frequency).
test = pd.date_range(start='1/1/2018', periods=5, freq='3M')
for x in test:
  print(df[str(x.date())])
# Out:
#                            Day  Symbol     Open     High      Low    Close  \
# Date
# 2018-01-31 11:00:00  Wednesday  ETHUSD  1093.00  1105.39  1090.00  1105.00
# 2018-01-31 10:00:00  Wednesday  ETHUSD  1087.40  1093.00  1085.15  1093.00
# 2018-01-31 09:00:00  Wednesday  ETHUSD  1090.00  1091.50  1083.38  1087.40
# 2018-01-31 08:00:00  Wednesday  ETHUSD  1088.00  1091.00  1078.20  1090.00
# 2018-01-31 07:00:00  Wednesday  ETHUSD  1097.09  1098.00  1080.50  1088.00
# 2018-01-31 06:00:00  Wednesday  ETHUSD  1094.00  1105.88  1094.00  1097.09
# 2018-01-31 05:00:00  Wednesday  ETHUSD  1095.00  1108.40  1092.99  1094.00
# 2018-01-31 04:00:00  Wednesday  ETHUSD  1092.93  1095.00  1074.31  1095.00
# 2018-01-31 03:00:00  Wednesday  ETHUSD  1087.00  1100.00  1082.00  1092.93
# 2018-01-31 02:00:00  Wednesday  ETHUSD  1093.10  1108.00  1077.99  1087.00
# 2018-01-31 01:00:00  Wednesday  ETHUSD  1117.05  1121.03  1091.00  1093.10
# ...

# %%
#Specify tz to set the timezone.
pd.date_range(start='1/1/2018', periods=5, tz='Asia/Tokyo')
# Out:
# DatetimeIndex(['2018-01-01 00:00:00+09:00', '2018-01-02 00:00:00+09:00',
#                '2018-01-03 00:00:00+09:00', '2018-01-04 00:00:00+09:00',
#                '2018-01-05 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Tokyo]', freq='D')
